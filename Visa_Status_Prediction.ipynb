# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("D:/visa_predictor/archive_1/us_perm_visas.csv", nrows=0)
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=154)

# %%
for col in df.columns:
    print(col)
# Out:
# add_these_pw_job_title_9089
# agent_city
# agent_firm_name
# agent_state
# application_type
# case_no
# case_number
# case_received_date
# case_status
# class_of_admission
# country_of_citizenship
# country_of_citzenship
# decision_date
# employer_address_1
# employer_address_2
# employer_city
# employer_country
# employer_decl_info_title
# employer_name
# employer_num_employees
# employer_phone
# employer_phone_ext
# employer_postal_code
# employer_state
# employer_yr_estab
# foreign_worker_info_alt_edu_experience
# foreign_worker_info_birth_country
# foreign_worker_info_city
# foreign_worker_info_education
# foreign_worker_info_education_other
# foreign_worker_info_inst
# foreign_worker_info_major
# foreign_worker_info_postal_code
# foreign_worker_info_rel_occup_exp
# foreign_worker_info_req_experience
# foreign_worker_info_state
# foreign_worker_info_training_comp
# foreign_worker_ownership_interest
# foreign_worker_yr_rel_edu_completed
# fw_info_alt_edu_experience
# fw_info_birth_country
# fw_info_education_other
# fw_info_postal_code
# fw_info_rel_occup_exp
# fw_info_req_experience
# fw_info_training_comp
# fw_info_yr_rel_edu_completed
# fw_ownership_interest
# ji_foreign_worker_live_on_premises
# ji_fw_live_on_premises
# ji_live_in_dom_svc_contract
# ji_live_in_domestic_service
# ji_offered_to_sec_j_foreign_worker
# ji_offered_to_sec_j_fw
# job_info_alt_cmb_ed_oth_yrs
# job_info_alt_combo_ed
# job_info_alt_combo_ed_exp
# job_info_alt_combo_ed_other
# job_info_alt_field
# job_info_alt_field_name
# job_info_alt_occ
# job_info_alt_occ_job_title
# job_info_alt_occ_num_months
# job_info_combo_occupation
# job_info_education
# job_info_education_other
# job_info_experience
# job_info_experience_num_months
# job_info_foreign_ed
# job_info_foreign_lang_req
# job_info_job_req_normal
# job_info_job_title
# job_info_major
# job_info_training
# job_info_training_field
# job_info_training_num_months
# job_info_work_city
# job_info_work_postal_code
# job_info_work_state
# naics_2007_us_code
# naics_2007_us_title
# naics_code
# naics_title
# naics_us_code
# naics_us_code_2007
# naics_us_title
# naics_us_title_2007
# orig_case_no
# orig_file_date
# preparer_info_emp_completed
# preparer_info_title
# pw_amount_9089
# pw_determ_date
# pw_expire_date
# pw_job_title_908
# pw_job_title_9089
# pw_level_9089
# pw_soc_code
# pw_soc_title
# pw_source_name_9089
# pw_source_name_other_9089
# pw_track_num
# pw_unit_of_pay_9089
# rec_info_barg_rep_notified
# recr_info_barg_rep_notified
# recr_info_coll_teach_comp_proc
# recr_info_coll_univ_teacher
# recr_info_employer_rec_payment
# recr_info_first_ad_start
# recr_info_job_fair_from
# recr_info_job_fair_to
# recr_info_on_campus_recr_from
# recr_info_on_campus_recr_to
# recr_info_pro_org_advert_from
# recr_info_pro_org_advert_to
# recr_info_prof_org_advert_from
# recr_info_prof_org_advert_to
# recr_info_professional_occ
# recr_info_radio_tv_ad_from
# recr_info_radio_tv_ad_to
# recr_info_second_ad_start
# recr_info_sunday_newspaper
# recr_info_swa_job_order_end
# recr_info_swa_job_order_start
# refile
# ri_1st_ad_newspaper_name
# ri_2nd_ad_newspaper_name
# ri_2nd_ad_newspaper_or_journal
# ri_campus_placement_from
# ri_campus_placement_to
# ri_coll_tch_basic_process
# ri_coll_teach_pro_jnl
# ri_coll_teach_select_date
# ri_employee_referral_prog_from
# ri_employee_referral_prog_to
# ri_employer_web_post_from
# ri_employer_web_post_to
# ri_job_search_website_from
# ri_job_search_website_to
# ri_layoff_in_past_six_months
# ri_local_ethnic_paper_from
# ri_local_ethnic_paper_to
# ri_posted_notice_at_worksite
# ri_pvt_employment_firm_from
# ri_pvt_employment_firm_to
# ri_us_workers_considered
# schd_a_sheepherder
# us_economic_sector
# wage_offer_from_9089
# wage_offer_to_9089
# wage_offer_unit_of_pay_9089
# wage_offered_from_9089
# wage_offered_to_9089
# wage_offered_unit_of_pay_9089

# %%
col_needed= [
    "case_received_date",
    "decision_date",
    "case_status",
    "application_type",
    "refile",
    "class_of_admission",
    "country_of_citizenship",
    "foreign_worker_info_birth_country",
    "foreign_worker_info_education",
    "foreign_worker_info_major",
    "foreign_worker_info_rel_occup_exp",
    "foreign_worker_info_req_experience",
    "foreign_worker_yr_rel_edu_completed",
    "foreign_worker_ownership_interest",
    "employer_state",
    "employer_country",
    "employer_num_employees",
    "employer_yr_estab",
    "job_info_job_title",
    "job_info_work_state",
    "job_info_work_city",
    "job_info_education",
    "job_info_major",
    "job_info_experience",
    "job_info_experience_num_months",
    "job_info_foreign_lang_req",
    "pw_level_9089",
    "pw_soc_code",
    "pw_soc_title",
    "pw_amount_9089",
    "pw_unit_of_pay_9089",
    "wage_offer_from_9089",
    "wage_offer_to_9089",
    "wage_offer_unit_of_pay_9089",
    "naics_code",
    "naics_title",
    "us_economic_sector"
]

df = pd.read_csv("D:/visa_predictor/archive_1/us_perm_visas.csv", usecols=col_needed)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_7296\3064990695.py:41: DtypeWarning: Columns (4,7,10,16,26,28,31,33,34,37,64,66,69,71,72,81,82,91,124,147,148,149,150) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("D:/visa_predictor/archive_1/us_perm_visas.csv", usecols=col_needed)

# %%
df.shape
# Out:
# (374362, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374362 entries, 0 to 374361
# Data columns (total 37 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   application_type                     135269 non-null  object
#  1   case_received_date                   239091 non-null  object
#  2   case_status                          374362 non-null  object
#  3   class_of_admission                   351517 non-null  object
#  4   country_of_citizenship               353729 non-null  object
#  5   decision_date                        374362 non-null  object
#  6   employer_country                     239019 non-null  object
#  7   employer_num_employees               239013 non-null  float64
#  8   employer_state                       374320 non-null  object
#  9   employer_yr_estab                    238958 non-null  float64
#  10  foreign_worker_info_birth_country    88628 non-null   object
#  11  foreign_worker_info_education        220709 non-null  object
#  12  foreign_worker_info_major            219390 non-null  object
#  13  foreign_worker_info_rel_occup_exp    88633 non-null   object
#  14  foreign_worker_info_req_experience   88635 non-null   object
#  15  foreign_worker_ownership_interest    88638 non-null   object
#  16  foreign_worker_yr_rel_edu_completed  83364 non-null   float64
#  17  job_info_education                   216313 non-null  object
#  18  job_info_experience                  239081 non-null  object
#  19  job_info_experience_num_months       133188 non-null  float64
#  20  job_info_foreign_lang_req            239076 non-null  object
#  21  job_info_job_title                   239049 non-null  object
#  22  job_info_major                       212477 non-null  object
#  23  job_info_work_city                   374260 non-null  object
#  24  job_info_work_state                  374259 non-null  object
#  25  naics_code                           88433 non-null   object
#  26  naics_title                          88433 non-null   object
#  27  pw_amount_9089                       372146 non-null  object
#  28  pw_level_9089                        346735 non-null  object
#  29  pw_soc_code                          373778 non-null  object
#  30  pw_soc_title                         372026 non-null  object
#  31  pw_unit_of_pay_9089                  372790 non-null  object
#  32  refile                               118079 non-null  object
#  33  us_economic_sector                   129068 non-null  object
#  34  wage_offer_from_9089                 259591 non-null  object
#  35  wage_offer_to_9089                   73634 non-null   object
#  36  wage_offer_unit_of_pay_9089          258446 non-null  object
# dtypes: float64(4), object(33)
# memory usage: 105.7+ MB

# %%
df.isnull().sum().sum()
# Out:
# 5172895

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# application_type                       239093
# case_received_date                     135271
# class_of_admission                      22845
# country_of_citizenship                  20633
# employer_country                       135343
# employer_num_employees                 135349
# employer_state                             42
# employer_yr_estab                      135404
# foreign_worker_info_birth_country      285734
# foreign_worker_info_education          153653
# foreign_worker_info_major              154972
# foreign_worker_info_rel_occup_exp      285729
# foreign_worker_info_req_experience     285727
# foreign_worker_ownership_interest      285724
# foreign_worker_yr_rel_edu_completed    290998
# job_info_education                     158049
# job_info_experience                    135281
# job_info_experience_num_months         241174
# job_info_foreign_lang_req              135286
# job_info_job_title                     135313
# job_info_major                         161885
# job_info_work_city                        102
# job_info_work_state                       103
# naics_code                             285929
# naics_title                            285929
# pw_amount_9089                           2216
# pw_level_9089                           27627
# pw_soc_code                               584
# pw_soc_title                             2336
# pw_unit_of_pay_9089                      1572
# refile                                 256283
# us_economic_sector                     245294
# wage_offer_from_9089                   114771
# wage_offer_to_9089                     300728
# wage_offer_unit_of_pay_9089            115916
# dtype: int64

# %%
missing_percent = (df.isnull().mean() * 100).sort_values(ascending=False)
missing_percent
# Out:
# wage_offer_to_9089                     80.330803
# foreign_worker_yr_rel_edu_completed    77.731714
# naics_title                            76.377677
# naics_code                             76.377677
# foreign_worker_info_birth_country      76.325589
# foreign_worker_info_rel_occup_exp      76.324253
# foreign_worker_info_req_experience     76.323719
# foreign_worker_ownership_interest      76.322917
# refile                                 68.458604
# us_economic_sector                     65.523210
# job_info_experience_num_months         64.422671
# application_type                       63.866792
# job_info_major                         43.242904
# job_info_education                     42.218227
# foreign_worker_info_major              41.396296
# foreign_worker_info_education          41.043963
# employer_yr_estab                      36.169269
# employer_num_employees                 36.154578
# employer_country                       36.152975
# job_info_job_title                     36.144961
# job_info_foreign_lang_req              36.137749
# job_info_experience                    36.136413
# case_received_date                     36.133742
# wage_offer_unit_of_pay_9089            30.963613
# wage_offer_from_9089                   30.657759
# pw_level_9089                           7.379755
# class_of_admission                      6.102382
# country_of_citizenship                  5.511510
# pw_soc_title                            0.623995
# pw_amount_9089                          0.591940
# pw_unit_of_pay_9089                     0.419914
# pw_soc_code                             0.155999
# job_info_work_state                     0.027513
# job_info_work_city                      0.027246
# employer_state                          0.011219
# decision_date                           0.000000
# case_status                             0.000000
# dtype: float64

# %%
cols_to_drop = [
    "wage_offer_to_9089",
    "foreign_worker_yr_rel_edu_completed",
    "naics_title",
    "naics_code",
    "foreign_worker_info_birth_country",
    "foreign_worker_info_rel_occup_exp",
    "foreign_worker_info_req_experience",
    "foreign_worker_ownership_interest",
    "refile",
    "us_economic_sector",
    "job_info_experience_num_months",
    "application_type"
]
df.drop(columns=cols_to_drop, inplace=True)

# %%
missing_percent = (df.isnull().mean() * 100).sort_values(ascending=False)
missing_percent
# Out:
# job_info_major                   43.242904
# job_info_education               42.218227
# foreign_worker_info_major        41.396296
# foreign_worker_info_education    41.043963
# employer_yr_estab                36.169269
# employer_num_employees           36.154578
# employer_country                 36.152975
# job_info_job_title               36.144961
# job_info_foreign_lang_req        36.137749
# job_info_experience              36.136413
# case_received_date               36.133742
# wage_offer_unit_of_pay_9089      30.963613
# wage_offer_from_9089             30.657759
# pw_level_9089                     7.379755
# class_of_admission                6.102382
# country_of_citizenship            5.511510
# pw_soc_title                      0.623995
# pw_amount_9089                    0.591940
# pw_unit_of_pay_9089               0.419914
# pw_soc_code                       0.155999
# job_info_work_state               0.027513
# job_info_work_city                0.027246
# employer_state                    0.011219
# case_status                       0.000000
# decision_date                     0.000000
# dtype: float64

# %%
numeric_cols = [
    "job_info_experience",
    "employer_yr_estab",
    "employer_num_employees",
    "wage_offer_from_9089",
    "pw_amount_9089"
]


for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

for col in numeric_cols:
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val)
# Out:
# C:\Users\pavan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
categorical_cols = [
    "job_info_major",
    "job_info_education",
    "foreign_worker_info_major",
    "foreign_worker_info_education",
    "job_info_foreign_lang_req",
    "pw_level_9089",
    "class_of_admission",
    "country_of_citizenship",
    "pw_soc_title",
    "pw_unit_of_pay_9089",
    "pw_soc_code",
    "job_info_work_state",
    "job_info_work_city",
    "employer_state",
    "case_status"
]

for col in categorical_cols:
    mode_val = df[col].mode()[0]
    df[col] = df[col].fillna(mode_val)

# %%
df["case_received_date"] = pd.to_datetime(df["case_received_date"], errors='coerce')
df["decision_date"] = pd.to_datetime(df["decision_date"], errors='coerce')

df = df.dropna(subset=["case_received_date", "decision_date"])

# %%
df = df.copy() 
flag_cols = ["job_info_foreign_lang_req", "pw_level_9089"]
for col in flag_cols:
    df.loc[:, col] = df[col].map({"Y": 1, "N": 0}).astype(float)
    df.loc[:, col] = df[col].fillna(0)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_7296\2800695479.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[:, col] = df[col].fillna(0)
# C:\Users\pavan\AppData\Local\Temp\ipykernel_7296\2800695479.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[:, col] = df[col].fillna(0)

# %%
missing_per_col = df.isnull().sum()
print(missing_per_col)
# Out:
# case_received_date                    0
# case_status                           0
# class_of_admission                    0
# country_of_citizenship                0
# decision_date                         0
# employer_country                     74
# employer_num_employees                0
# employer_state                        0
# employer_yr_estab                     0
# foreign_worker_info_education         0
# foreign_worker_info_major             0
# job_info_education                    0
# job_info_experience              239091
# job_info_foreign_lang_req             0
# job_info_job_title                   44
# job_info_major                        0
# job_info_work_city                    0
# job_info_work_state                   0
# pw_amount_9089                        0
# pw_level_9089                         0
# pw_soc_code                           0
# pw_soc_title                          0
# pw_unit_of_pay_9089                   0
# wage_offer_from_9089                  0
# wage_offer_unit_of_pay_9089        1221
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 239091 entries, 135269 to 374361
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   case_received_date             239091 non-null  datetime64[ns]
#  1   case_status                    239091 non-null  object
#  2   class_of_admission             239091 non-null  object
#  3   country_of_citizenship         239091 non-null  object
#  4   decision_date                  239091 non-null  datetime64[ns]
#  5   employer_country               239017 non-null  object
#  6   employer_num_employees         239091 non-null  float64
#  7   employer_state                 239091 non-null  object
#  8   employer_yr_estab              239091 non-null  float64
#  9   foreign_worker_info_education  239091 non-null  object
#  10  foreign_worker_info_major      239091 non-null  object
#  11  job_info_education             239091 non-null  object
#  12  job_info_experience            0 non-null       float64
#  13  job_info_foreign_lang_req      239091 non-null  object
#  14  job_info_job_title             239047 non-null  object
#  15  job_info_major                 239091 non-null  object
#  16  job_info_work_city             239091 non-null  object
#  17  job_info_work_state            239091 non-null  object
#  18  pw_amount_9089                 239091 non-null  float64
#  19  pw_level_9089                  239091 non-null  object
#  20  pw_soc_code                    239091 non-null  object
#  21  pw_soc_title                   239091 non-null  object
#  22  pw_unit_of_pay_9089            239091 non-null  object
#  23  wage_offer_from_9089           239091 non-null  float64
#  24  wage_offer_unit_of_pay_9089    237870 non-null  object
# dtypes: datetime64[ns](2), float64(5), object(18)
# memory usage: 47.4+ MB

# %%
# handling missing values
df["employer_country"] = df["employer_country"].fillna("Unknown")
df["job_info_job_title"] = df["job_info_job_title"].fillna("Unknown")


df["job_info_experience"] = df["job_info_experience"].map({"Y": 1, "N": 0}).fillna(0)


df["wage_offer_unit_of_pay_9089"] = pd.to_numeric(df["wage_offer_unit_of_pay_9089"], errors='coerce').fillna(0)

# %%
print(df[["employer_country", "job_info_experience", "job_info_job_title", "wage_offer_unit_of_pay_9089"]].isnull().sum())
# Out:
# employer_country               0
# job_info_experience            0
# job_info_job_title             0
# wage_offer_unit_of_pay_9089    0
# dtype: int64

# %%
df.isnull()
# Out:
#         case_received_date  case_status  class_of_admission  \
# 135269               False        False               False
# 135270               False        False               False
# 135271               False        False               False
# 135272               False        False               False
# 135273               False        False               False
# ...                    ...          ...                 ...
# 374357               False        False               False
# 374358               False        False               False
# 374359               False        False               False
# 374360               False        False               False
# 374361               False        False               False
#
#         country_of_citizenship  decision_date  employer_country  \
# 135269                   False          False             False
# 135270                   False          False             False
# 135271                   False          False             False
# 135272                   False          False             False
# 135273                   False          False             False
# ...                        ...            ...               ...
# 374357                   False          False             False
# 374358                   False          False             False
# 374359                   False          False             False
# 374360                   False          False             False
# 374361                   False          False             False
#
#         employer_num_employees  employer_state  employer_yr_estab  \
# 135269                   False           False              False
# 135270                   False           False              False
# 135271                   False           False              False
# 135272                   False           False              False
# 135273                   False           False              False
# ...                        ...             ...                ...
# 374357                   False           False              False
# 374358                   False           False              False
# 374359                   False           False              False
# 374360                   False           False              False
# 374361                   False           False              False
#
#         foreign_worker_info_education  ...  job_info_major  \
# 135269                          False  ...           False
# 135270                          False  ...           False
# 135271                          False  ...           False
# 135272                          False  ...           False
# 135273                          False  ...           False
# ...                               ...  ...             ...
# 374357                          False  ...           False
# 374358                          False  ...           False
# 374359                          False  ...           False
# 374360                          False  ...           False
# 374361                          False  ...           False
#
#         job_info_work_city  job_info_work_state  pw_amount_9089  \
# 135269               False                False           False
# 135270               False                False           False
# 135271               False                False           False
# 135272               False                False           False
# 135273               False                False           False
# ...                    ...                  ...             ...
# 374357               False                False           False
# 374358               False                False           False
# 374359               False                False           False
# 374360               False                False           False
# 374361               False                False           False
#
#         pw_level_9089  pw_soc_code  pw_soc_title  pw_unit_of_pay_9089  \
# 135269          False        False         False                False
# 135270          False        False         False                False
# 135271          False        False         False                False
# 135272          False        False         False                False
# 135273          False        False         False                False
# ...               ...          ...           ...                  ...
# 374357          False        False         False                False
# 374358          False        False         False                False
# 374359          False        False         False                False
# 374360          False        False         False                False
# 374361          False        False         False                False
#
#         wage_offer_from_9089  wage_offer_unit_of_pay_9089
# 135269                 False                        False
# 135270                 False                        False
# 135271                 False                        False
# 135272                 False                        False
# 135273                 False                        False
# ...                      ...                          ...
# 374357                 False                        False
# 374358                 False                        False
# 374359                 False                        False
# 374360                 False                        False
# 374361                 False                        False
#
# [239091 rows x 25 columns]

# %%
missing_per_col = df.isnull().sum()
print(missing_per_col)
# Out:
# case_received_date               0
# case_status                      0
# class_of_admission               0
# country_of_citizenship           0
# decision_date                    0
# employer_country                 0
# employer_num_employees           0
# employer_state                   0
# employer_yr_estab                0
# foreign_worker_info_education    0
# foreign_worker_info_major        0
# job_info_education               0
# job_info_experience              0
# job_info_foreign_lang_req        0
# job_info_job_title               0
# job_info_major                   0
# job_info_work_city               0
# job_info_work_state              0
# pw_amount_9089                   0
# pw_level_9089                    0
# pw_soc_code                      0
# pw_soc_title                     0
# pw_unit_of_pay_9089              0
# wage_offer_from_9089             0
# wage_offer_unit_of_pay_9089      0
# dtype: int64

# %%
print(df[["job_info_foreign_lang_req", "pw_level_9089"]].head())
print(df[["job_info_foreign_lang_req", "pw_level_9089"]].isnull().sum())
# Out:
#        job_info_foreign_lang_req pw_level_9089
# 135269                       0.0             0
# 135270                       0.0             0
# 135271                       0.0             0
# 135272                       0.0             0
# 135273                       0.0             0
# job_info_foreign_lang_req    0
# pw_level_9089                0
# dtype: int64

# %%
# Calculate processing days
df["processing_days"] = (df["decision_date"] - df["case_received_date"]).dt.days

# %%
df.head
# Out:
# <bound method NDFrame.head of        case_received_date case_status class_of_admission  \
# 135269         2013-11-19   Certified               H-1B
# 135270         2013-11-12      Denied               H-1B
# 135271         2013-11-27      Denied               H-1B
# 135272         2013-11-13   Certified                E-2
# 135273         2013-11-12      Denied               H-1B
# ...                   ...         ...                ...
# 374357         2016-12-29   Withdrawn               H-1B
# 374358         2016-12-30   Withdrawn                L-1
# 374359         2016-12-30   Withdrawn               H-1B
# 374360         2016-12-30   Withdrawn                B-2
# 374361         2016-12-30   Withdrawn               H-1B
#
#        country_of_citizenship decision_date          employer_country  \
# 135269                  INDIA    2015-05-29  UNITED STATES OF AMERICA
# 135270            SOUTH KOREA    2015-06-26  UNITED STATES OF AMERICA
# 135271                GERMANY    2014-10-16  UNITED STATES OF AMERICA
# 135272            SOUTH KOREA    2015-05-26  UNITED STATES OF AMERICA
# 135273            SOUTH KOREA    2015-06-26  UNITED STATES OF AMERICA
# ...                       ...           ...                       ...
# 374357            SOUTH KOREA    2016-12-30  UNITED STATES OF AMERICA
# 374358                VIETNAM    2016-12-30  UNITED STATES OF AMERICA
# 374359                  INDIA    2016-12-30  UNITED STATES OF AMERICA
# 374360            SOUTH KOREA    2016-12-30  UNITED STATES OF AMERICA
# 374361                  CHINA    2016-12-30  UNITED STATES OF AMERICA
#
#         employer_num_employees employer_state  employer_yr_estab  \
# 135269                  1935.0      WISCONSIN             1959.0
# 135270                   350.0    MISSISSIPPI             1988.0
# 135271                     4.0       COLORADO             1996.0
# 135272                     8.0     WASHINGTON             2010.0
# 135273                   350.0    MISSISSIPPI             1988.0
# ...                        ...            ...                ...
# 374357                     3.0             CA             2014.0
# 374358                 63000.0             WA             1975.0
# 374359                    33.0             MI             2010.0
# 374360                    16.0             AZ             2013.0
# 374361                 54000.0             CA             1968.0
#
#        foreign_worker_info_education  ... job_info_work_city  \
# 135269                    Bachelor's  ...           Waukesha
# 135270                      Master's  ...          Itta Bena
# 135271                     Doctorate  ...             Aurora
# 135272                      Master's  ...           Lynnwood
# 135273                      Master's  ...          Itta Bena
# ...                              ...  ...                ...
# 374357                   Associate's  ...            Anaheim
# 374358                    Bachelor's  ...          Cambridge
# 374359                      Master's  ...          Ypsilanti
# 374360                      Master's  ...            Phoenix
# 374361                      Master's  ...       Fort Collins
#
#        job_info_work_state  pw_amount_9089 pw_level_9089 pw_soc_code  \
# 135269           WISCONSIN         85592.0             0     17-2112
# 135270         MISSISSIPPI         85592.0             0     51-3022
# 135271            COLORADO         85592.0             0     19-1029
# 135272          WASHINGTON         85592.0             0     13-1161
# 135273         MISSISSIPPI         85592.0             0     51-3022
# ...                    ...             ...           ...         ...
# 374357                  CA         85592.0             0     43-9061
# 374358                  MA         85592.0             0     15-1132
# 374359                  MI         85592.0             0     15-1121
# 374360                  AZ         85592.0             0     43-3031
# 374361                  CO         85592.0             0     17-2072
#
#                                              pw_soc_title pw_unit_of_pay_9089  \
# 135269                               Industrial Engineers                Year
# 135270       Meat, Poultry, and Fish Cutters and Trimmers                Year
# 135271                   Biological Scientists, All Other                Year
# 135272  Market Research Analysts and Marketing Special...                Year
# 135273       Meat, Poultry, and Fish Cutters and Trimmers                Year
# ...                                                   ...                 ...
# 374357                             Office Clerks, General                Year
# 374358                  Software Developers, Applications                Year
# 374359                          Computer Systems Analysts                Year
# 374360       Bookkeeping, Accounting, and Auditing Clerks                Year
# 374361             Electronics Engineers, Except Computer                Year
#
#        wage_offer_from_9089  wage_offer_unit_of_pay_9089 processing_days
# 135269              90750.0                          0.0             556
# 135270              90750.0                          0.0             591
# 135271              90750.0                          0.0             323
# 135272              90750.0                          0.0             559
# 135273              90750.0                          0.0             591
# ...                     ...                          ...             ...
# 374357              90750.0                          0.0               1
# 374358              90750.0                          0.0               0
# 374359              90750.0                          0.0               0
# 374360              90750.0                          0.0               0
# 374361              90750.0                          0.0               0
#
# [239091 rows x 26 columns]>

# %%
df.to_csv('visa_dataset.csv', index=False)
